# %% [markdown]
# P, O, N Cycling
# ===============
#
# **Author:** Ulrich G Wortmann

# %% [markdown]
# ### Goal

# %% [markdown]
# This assignment is meant to help you write your notes on phosphate, nitrate, and oxygen cycling. Specifically, this assignment will allow you to create the necessary figures, and challenges you to make your own observations and descriptions. In other words, each subsection will yield an independent Obsidian note. If you already have notes on these topics, please add to them.

# %% [markdown]
# ### Primary Productionyy

# %% [markdown]
# Photosynthesis uses oxidized carbon (CO<sub>2</sub>) to create reduced carbon (organic matter OM). This process additionally requires nitrate and phosphate, resulting in organic matter with fairly uniform C:N:P ratios, the so called Redfield ratio (106:16:1). In addition, photosynthesis creates oxygen as a byproduct.
#
# Settling organic matter transports these elements from the surface ocean into the deep ocean. This process is termed export production and/or biological carbon pump.
#
# Organic matter decomposes while sinking into the deep ocean, a
# process that consumes oxygen, and liberates phosphate and nitrate. This process is referred to as remineralization or respiration.  Ocean mixing via the thermohaline circulation returns those nutrients back to the surface ocean.
#
# ![img](./my_images/OM_cycling.png)

# %% [markdown]
# #### Phosphate

# %% [markdown]
# In the left pane you should see a file called `woa_phosphate.ipynb`. Please open it into a new tab. If you execute the code in that file, you should see a map of the phosphate concentrations in the ocean.
#
# 1.  Name two regions where organic matter export removes the majority of phosphate (2  pts)
# 2.  Name two regions where ocean mixing returns phosphate to the surface ocean (2 pts).
# 3.  In line 12, change the value of `z_min_max` to `[0, 4, 0.2]`, and set the ocean depth to 2000 (line 6), and rerun the code.  Can you confirm that the phosphate values in the deep ocean are higher than in the surface ocean? 2pts
# 4.  Speculate why the phosphate concentrations in the Pacific deep ocean are higher than in the Atlantic deep ocean. Hint: Look at your note for the thermohaline circulation. 4 pts
# 5.  Where does the phosphate in the ocean come from? Name two minerals including their chemical formula. 2 pts
# 6.  How much of the particulate organic phosphor export from the surface ocean to the deep oceans is buried and how much is remineralized? 2 pts

# %% [markdown]
# #### Oxygen

# %% [markdown]
# Unlike phosphate, oxygen is also affected by temperature since the solubility of oxygen in water depends on the water temperature.
#
# ![img](./my_images/o-vs-t.png)
#
# Use the `Oxygen.ipynb` and `Temperature.ipynb` notebooks to generate maps for oxygen and temperature.
#
# 1.  Compare both maps, and describe if there is a (rough) correlation between both datasets. Describe in words how the data correlates. 2 pts
# 2.  Create an oxygen concentration map for the oxygen concentration at 800 meter below sealevel (mbsl). Compare the values against the map for 50 mbsl, and describe the difference in words. Explain what is going on. 4 pts
# 3.  Photosynthesis creates oxygen, and remineralization consumes oxygen. However, not all organic matter is remineralized. As such there is a constant surplus of oxygen, which would lead to ever increasing oxygen concentrations. Which process balances the surplus oxygen from photosynthetic production? 2 pts
#
# At this point, it may be necessary to delete some of the data files that were downloaded. In the left pane, select all files with the `*.nc` extension and delete them.

# %% [markdown]
# #### Nitrate

# %% [markdown]
# 1.  Make a list with the nitrogen species (Names and Formula) that are relevant in the biogeochemical nitrogen cycle. 4 pts
# 2.  Since not all organic matter is remineralized, there is a constant loss of nitrate. Unlike phosphate, nitrate loss occurs through two additional processes. What are the names of these processes? 4 pts
# 3.  Which two sources of nitrate and/or ammonium compensate for the loss of nitrate in the ocean? 2 pts
# 4.  Explain the term "Ammonification" 2 pts
# 5.  Provide the reactions for Ammonium and Nitrite Oxidation 4 pts
# 6.  What is the name for the combined Ammonium and Nitrite Oxidation reactions. 2 pts
# 7.  What is the relevance of these processes for atmospheric dinitrogen gas? 2 pts
# 8.  Generate a map for the nitrate concentration at 50 mbsl. Compare the values against the phosphate map for 50 mbsl.  2 pts
# 9.  Do they show a similar spatial distribution? Describe in your own words. 2 pts
# 10. Both, nitrate and phosphate are nutrients that  are required for photosynthesis.  However, nitrate concentrations are about an order of magnitude higher than phosphate concentrations. Explain why 4  pts
# 11. Ignoring for a moment that the surface rocks on mars are oxidized, why is the atmosphere of mars so different from earth. 2  pts
#     1.  Mars: 95% CO<sub>2</sub>, 3% N<sub>2</sub>, 1.6% Ar, plus traces
#     2.  Earth: 78% N<sub>2</sub>, 21% O<sub>2</sub>, plus traces.

# %% [markdown]
# ## Submission instructions

# %% [markdown]
# Submit the following Obsidian notes as pdf file on Quercus
#
# -   Phosphate cycling
# -   Oxygen cycling
# -   Nitrate cycling

# %% [markdown]
# ### Additional Marking pointers

# %% [markdown]
# -   Write your note in such a way that all  images are scaled to a with of 800 pixel. 2 pts
# -   Make sure your notes are link to other notes where appropriate (i.e., Phosphate, would be a link to your Phosphate note etc.) 2  pts
